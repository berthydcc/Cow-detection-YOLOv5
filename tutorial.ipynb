# %% [markdown]
# <a href="https://colab.research.google.com/github/berthydcc/Cow-detection-YOLOv5/blob/main/tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a align="left" href="https://ultralytics.com/yolov5" target="_blank">
# <img width="1024", src="https://user-images.githubusercontent.com/26833433/125273437-35b3fc00-e30d-11eb-9079-46f313325424.png"></a>
#
# This is the **official YOLOv5 🚀 notebook** by **Ultralytics**, and is freely available for redistribution under the [GPL-3.0 license](https://choosealicense.com/licenses/gpl-3.0/).
# For more information please visit https://github.com/ultralytics/yolov5 and https://ultralytics.com. Thank you!

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-184-g9d8ed37 torch 1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.2/78.2 GB disk)

# %%
# !unzip -q ../train_data.zip -d ../

# %% [markdown]
# # 1. Inference
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           path/  # directory
#                           path/*.jpg  # glob
#                           'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                           'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --weights runs/train/exp15/weights/best.pt --img 640 --conf 0.35 --source ../video1.mp4
# Out:
# detect: weights=['runs/train/exp15/weights/best.pt'], source=../video1.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-184-g9d8ed37 torch 1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 444 layers, 86173414 parameters, 0 gradients, 204.0 GFLOPs
# video 1/1 (1/498) /content/video1.mp4: 384x640 Done. (0.143s)
# video 1/1 (2/498) /content/video1.mp4: 384x640 Done. (0.133s)
# video 1/1 (3/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (4/498) /content/video1.mp4: 384x640 Done. (0.123s)
# video 1/1 (5/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (6/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (7/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (8/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (9/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (10/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (11/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (12/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (13/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (14/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (15/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (16/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (17/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (18/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (19/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (20/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (21/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (22/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (23/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (24/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (25/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (26/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (27/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (28/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (29/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (30/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (31/498) /content/video1.mp4: 384x640 Done. (0.131s)
# video 1/1 (32/498) /content/video1.mp4: 384x640 Done. (0.130s)
# video 1/1 (33/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (34/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (35/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (36/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (37/498) /content/video1.mp4: 384x640 Done. (0.130s)
# video 1/1 (38/498) /content/video1.mp4: 384x640 Done. (0.130s)
# video 1/1 (39/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (40/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (41/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (42/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (43/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (44/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (45/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (46/498) /content/video1.mp4: 384x640 Done. (0.130s)
# video 1/1 (47/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (48/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (49/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (50/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (51/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (52/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (53/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (54/498) /content/video1.mp4: 384x640 Done. (0.130s)
# video 1/1 (55/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (56/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (57/498) /content/video1.mp4: 384x640 Done. (0.130s)
# video 1/1 (58/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (59/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (60/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (61/498) /content/video1.mp4: 384x640 Done. (0.130s)
# video 1/1 (62/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (63/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (64/498) /content/video1.mp4: 384x640 Done. (0.130s)
# video 1/1 (65/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (66/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (67/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (68/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (69/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (70/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (71/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (72/498) /content/video1.mp4: 384x640 Done. (0.130s)
# video 1/1 (73/498) /content/video1.mp4: 384x640 Done. (0.131s)
# video 1/1 (74/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (75/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (76/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (77/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (78/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (79/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (80/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (81/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (82/498) /content/video1.mp4: 384x640 Done. (0.130s)
# video 1/1 (83/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (84/498) /content/video1.mp4: 384x640 Done. (0.130s)
# video 1/1 (85/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (86/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (87/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (88/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (89/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (90/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (91/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (92/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (93/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (94/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (95/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (96/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (97/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (98/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (99/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (100/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (101/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (102/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (103/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (104/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (105/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (106/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (107/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (108/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (109/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (110/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (111/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (112/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (113/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (114/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (115/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (116/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (117/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (118/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (119/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (120/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (121/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (122/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (123/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (124/498) /content/video1.mp4: 384x640 Done. (0.130s)
# video 1/1 (125/498) /content/video1.mp4: 384x640 Done. (0.130s)
# video 1/1 (126/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (127/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (128/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (129/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (130/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (131/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (132/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (133/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (134/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (135/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (136/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (137/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (138/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (139/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (140/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (141/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (142/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (143/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (144/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (145/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (146/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (147/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (148/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (149/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (150/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (151/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (152/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (153/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (154/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (155/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (156/498) /content/video1.mp4: 384x640 Done. (0.130s)
# video 1/1 (157/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (158/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (159/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (160/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (161/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (162/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (163/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (164/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (165/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (166/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (167/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (168/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (169/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (170/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (171/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (172/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (173/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (174/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (175/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (176/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (177/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (178/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (179/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (180/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (181/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (182/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (183/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (184/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (185/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (186/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (187/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (188/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (189/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (190/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (191/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (192/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (193/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (194/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (195/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (196/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (197/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (198/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (199/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (200/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (201/498) /content/video1.mp4: 384x640 Done. (0.130s)
# video 1/1 (202/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (203/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (204/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (205/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (206/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (207/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (208/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (209/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (210/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (211/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (212/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (213/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (214/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (215/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (216/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (217/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (218/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (219/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (220/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (221/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (222/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (223/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (224/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (225/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (226/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (227/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (228/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (229/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (230/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (231/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (232/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (233/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (234/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (235/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (236/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (237/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (238/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (239/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (240/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (241/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (242/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (243/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (244/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (245/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (246/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (247/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (248/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (249/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (250/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (251/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (252/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (253/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (254/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (255/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (256/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (257/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (258/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (259/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (260/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (261/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (262/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (263/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (264/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (265/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (266/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (267/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (268/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (269/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (270/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (271/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (272/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (273/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (274/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (275/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (276/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (277/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (278/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (279/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (280/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (281/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (282/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (283/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (284/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (285/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (286/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (287/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (288/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (289/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (290/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (291/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (292/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (293/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (294/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (295/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (296/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (297/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (298/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (299/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (300/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (301/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (302/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (303/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (304/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (305/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (306/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (307/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (308/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (309/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (310/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (311/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (312/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (313/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (314/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (315/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (316/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (317/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (318/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (319/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (320/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (321/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (322/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (323/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (324/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (325/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (326/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (327/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (328/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (329/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (330/498) /content/video1.mp4: 384x640 Done. (0.125s)
# video 1/1 (331/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (332/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (333/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (334/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (335/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (336/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (337/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (338/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (339/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (340/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (341/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (342/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (343/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (344/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (345/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (346/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (347/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (348/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (349/498) /content/video1.mp4: 384x640 Done. (0.130s)
# video 1/1 (350/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (351/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (352/498) /content/video1.mp4: 384x640 Done. (0.125s)
# video 1/1 (353/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (354/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (355/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (356/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (357/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (358/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (359/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (360/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (361/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (362/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (363/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (364/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (365/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (366/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (367/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (368/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (369/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (370/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (371/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (372/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (373/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (374/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (375/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (376/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (377/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (378/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (379/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (380/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (381/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (382/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (383/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (384/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (385/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (386/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (387/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (388/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (389/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (390/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (391/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (392/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (393/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (394/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (395/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (396/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (397/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (398/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (399/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (400/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (401/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (402/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (403/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (404/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (405/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (406/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (407/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (408/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (409/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (410/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (411/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (412/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (413/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (414/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (415/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (416/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (417/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (418/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (419/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (420/498) /content/video1.mp4: 384x640 Done. (0.125s)
# video 1/1 (421/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (422/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (423/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (424/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (425/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (426/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (427/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (428/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (429/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (430/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (431/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (432/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (433/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (434/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (435/498) /content/video1.mp4: 384x640 Done. (0.125s)
# video 1/1 (436/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (437/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (438/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (439/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (440/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (441/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (442/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (443/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (444/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (445/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (446/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (447/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (448/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (449/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (450/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (451/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (452/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (453/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (454/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (455/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (456/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (457/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (458/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (459/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (460/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (461/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (462/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (463/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (464/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (465/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (466/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (467/498) /content/video1.mp4: 384x640 Done. (0.130s)
# video 1/1 (468/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (469/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (470/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (471/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (472/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (473/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (474/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (475/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (476/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (477/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (478/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (479/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (480/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (481/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (482/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (483/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (484/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (485/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (486/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (487/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (488/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (489/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (490/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (491/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (492/498) /content/video1.mp4: 384x640 Done. (0.126s)
# video 1/1 (493/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (494/498) /content/video1.mp4: 384x640 Done. (0.129s)
# video 1/1 (495/498) /content/video1.mp4: 384x640 Done. (0.128s)
# video 1/1 (496/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (497/498) /content/video1.mp4: 384x640 Done. (0.127s)
# video 1/1 (498/498) /content/video1.mp4: 384x640 Done. (0.125s)
# Speed: 0.6ms pre-process, 128.1ms inference, 0.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/127574988-6a558aa1-d268-44b9-bf6b-62d4c605cc72.jpg" width="600">

# %% [markdown]
# # 2. Validate
# Validate a model's accuracy on [COCO](https://cocodataset.org/#home) val or test-dev datasets. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag. Note that `pycocotools` metrics may be ~1% better than the equivalent repo metrics, as is visible below, due to slight differences in mAP computation.

# %% [markdown]
# ## COCO val
# Download [COCO val 2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L14) dataset (1GB - 5000 images), and test model accuracy.

# %%
# Download COCO val
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip
# Out:
#   0%|          | 0.00/780M [00:00<?, ?B/s]

# %%
# Run YOLOv5x on COCO val
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half
# Out:
# val: data=/content/yolov5/data/coco.yaml, weights=['yolov5x.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.65, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v6.1-174-gc4cb7c6 torch 1.11.0+cu113 CUDA:0 (Tesla V100-SXM2-16GB, 16160MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5x.pt to yolov5x.pt...
# 100% 166M/166M [00:05<00:00, 33.5MB/s]
#
# Fusing layers...
# YOLOv5x summary: 444 layers, 86705005 parameters, 0 gradients
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 49.6MB/s]
# val: Scanning '/content/datasets/coco/val2017' images and labels...4952 found, 48 missing, 0 empty, 0 corrupt: 100% 5000/5000 [00:00<00:00, 10667.19it/s]
# val: New cache created: /content/datasets/coco/val2017.cache
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 157/157 [00:58<00:00,  2.70it/s]
#                  all       5000      36335      0.743      0.626      0.683      0.496
# Speed: 0.1ms pre-process, 4.8ms inference, 1.2ms NMS per image at shape (32, 3, 640, 640)
#
# Evaluating pycocotools mAP... saving runs/val/exp/yolov5x_predictions.json...
# loading annotations into memory...
# Done (t=0.38s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=5.42s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=72.67s).
# Accumulating evaluation results...
# DONE (t=13.48s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.506
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.688
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.549
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.340
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.557
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.651
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.382
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.631
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.684
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.528
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.737
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.833
# Results saved to runs/val/exp

# %% [markdown]
# ## COCO test
# Download [COCO test2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L15) dataset (7GB - 40,000 images), to test model accuracy on test-dev set (**20,000 images, no labels**). Results are saved to a `*.json` file which should be **zipped** and submitted to the evaluation server at https://competitions.codalab.org/competitions/20794.

# %%
# Download COCO test-dev2017
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017labels.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip
# !f="test2017.zip" && curl http://images.cocodataset.org/zips/$f -o $f && unzip -q $f -d ../datasets/coco/images

# %%
# Run YOLOv5x on COCO test
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half --task test

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://roboflow.com/?ref=ultralytics"><img width="1000" src="https://uploads-ssl.webflow.com/5f6bc60e665f54545a1e52a5/615627e5824c9c6195abfda9_computer-vision-cycle.png"/></a></p>
# Close the active learning loop by sampling images from your inference conditions with the `roboflow` pip package
# <br><br>
#
# Train a YOLOv5s model on the [COCO128](https://www.kaggle.com/ultralytics/coco128) dataset with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`.
#
# - **Pretrained [Models](https://github.com/ultralytics/yolov5/tree/master/models)** are downloaded
# automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases)
# - **[Datasets](https://github.com/ultralytics/yolov5/tree/master/data)** available for autodownload include: [COCO](https://github.com/ultralytics/yolov5/blob/master/data/coco.yaml), [COCO128](https://github.com/ultralytics/yolov5/blob/master/data/coco128.yaml), [VOC](https://github.com/ultralytics/yolov5/blob/master/data/VOC.yaml), [Argoverse](https://github.com/ultralytics/yolov5/blob/master/data/Argoverse.yaml), [VisDrone](https://github.com/ultralytics/yolov5/blob/master/data/VisDrone.yaml), [GlobalWheat](https://github.com/ultralytics/yolov5/blob/master/data/GlobalWheat2020.yaml), [xView](https://github.com/ultralytics/yolov5/blob/master/data/xView.yaml), [Objects365](https://github.com/ultralytics/yolov5/blob/master/data/Objects365.yaml), [SKU-110K](https://github.com/ultralytics/yolov5/blob/master/data/SKU-110K.yaml).
# - **Training Results** are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.
# <br><br>
#
# ## Train on Custom Data with Roboflow 🌟 NEW
#
# [Roboflow](https://roboflow.com/?ref=ultralytics) enables you to easily **organize, label, and prepare** a high quality dataset with your own custom data. Roboflow also makes it easy to establish an active learning pipeline, collaborate with your team on dataset improvement, and integrate directly into your model building workflow with the `roboflow` pip package.
#
# - Custom Training Example: [https://blog.roboflow.com/how-to-train-yolov5-on-a-custom-dataset/](https://blog.roboflow.com/how-to-train-yolov5-on-a-custom-dataset/?ref=ultralytics)
# - Custom Training Notebook: [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roboflow-ai/yolov5-custom-training-tutorial/blob/main/yolov5-custom-training.ipynb)
# <br>
#
# <p align=""><a href="https://roboflow.com/?ref=ultralytics"><img width="480" src="https://uploads-ssl.webflow.com/5f6bc60e665f54545a1e52a5/6152a275ad4b4ac20cd2e21a_roboflow-annotate.gif"/></a></p>Label images lightning fast (including with model-assisted labeling)

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 2 --epochs 3 --data custom_data.yaml --weights yolov5x.pt --nosave --cache
# Out:
# train: weights=yolov5x.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=2, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-184-g9d8ed37 torch 1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      8800  models.common.Conv                      [3, 80, 6, 2, 2]
#   1                -1  1    115520  models.common.Conv                      [80, 160, 3, 2]
#   2                -1  4    309120  models.common.C3                        [160, 160, 4]
#   3                -1  1    461440  models.common.Conv                      [160, 320, 3, 2]
#   4                -1  8   2259200  models.common.C3                        [320, 320, 8]
#   5                -1  1   1844480  models.common.Conv                      [320, 640, 3, 2]
#   6                -1 12  13125120  models.common.C3                        [640, 640, 12]
#   7                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 2]
#   8                -1  4  19676160  models.common.C3                        [1280, 1280, 4]
#   9                -1  1   4099840  models.common.SPPF                      [1280, 1280, 5]
#  10                -1  1    820480  models.common.Conv                      [1280, 640, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  4   5332480  models.common.C3                        [1280, 640, 4, False]
#  14                -1  1    205440  models.common.Conv                      [640, 320, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  4   1335040  models.common.C3                        [640, 320, 4, False]
#  18                -1  1    922240  models.common.Conv                      [320, 320, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  4   4922880  models.common.C3                        [640, 640, 4, False]
#  21                -1  1   3687680  models.common.Conv                      [640, 640, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  4  19676160  models.common.C3                        [1280, 1280, 4, False]
#  24      [17, 20, 23]  1     40374  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [320, 640, 1280]]
# Model summary: 567 layers, 86217814 parameters, 86217814 gradients, 204.2 GFLOPs
#
# Transferred 739/745 items from yolov5x.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 123 weight (no decay), 126 weight, 126 bias
# albumentations: version 1.0.3 required by YOLOv5, but version 0.1.12 is currently installed
# train: Scanning '/content/yolov5/../train_data/labels/train.cache' images and labels... 22 found, 0 missing, 0 empty, 0 corrupt: 100% 22/22 [00:00<?, ?it/s]
# train: Caching images (0.0GB ram): 100% 22/22 [00:00<00:00, 497.91it/s]
# val: Scanning '/content/yolov5/../train_data/labels/val.cache' images and labels... 8 found, 0 missing, 0 empty, 0 corrupt: 100% 8/8 [00:00<?, ?it/s]
# val: Caching images (0.0GB ram): 100% 8/8 [00:00<00:00, 154.60it/s]
# Plotting labels to runs/train/exp15/labels.jpg...
#
# AutoAnchor: 4.04 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp15
# Starting training for 3 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#        0/2     3.12G    0.1066   0.05029         0        10       640: 100% 11/11 [00:25<00:00,  2.28s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:01<00:00,  1.28it/s]
#                  all          8         27    0.00792      0.704     0.0184     0.0031
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#        1/2     3.33G   0.09825   0.04935         0        14       640: 100% 11/11 [00:20<00:00,  1.84s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:01<00:00,  1.34it/s]
#                  all          8         27    0.00875      0.778     0.0244    0.00419
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#        2/2     3.34G   0.09398   0.05097         0        25       640: 100% 11/11 [00:20<00:00,  1.83s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:01<00:00,  1.34it/s]
#                  all          8         27    0.00875      0.778     0.0293    0.00581
#
# 3 epochs completed in 0.021 hours.
# Optimizer stripped from runs/train/exp15/weights/last.pt, 173.1MB
# Optimizer stripped from runs/train/exp15/weights/best.pt, 173.1MB
#
# Validating runs/train/exp15/weights/best.pt...
# Fusing layers...
# Model summary: 444 layers, 86173414 parameters, 0 gradients, 204.0 GFLOPs
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:01<00:00,  1.12it/s]
#                  all          8         27    0.00875      0.778     0.0284    0.00561
# Results saved to runs/train/exp15

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Weights & Biases Logging 🌟 NEW
#
# [Weights & Biases](https://wandb.ai/site?utm_campaign=repo_yolo_notebook) (W&B) is now integrated with YOLOv5 for real-time visualization and cloud logging of training runs. This allows for better run comparison and introspection, as well improved visibility and collaboration for teams. To enable W&B `pip install wandb`, and then train normally (you will be guided through setup on first use).
#
# During training you will see live updates at [https://wandb.ai/home](https://wandb.ai/home?utm_campaign=repo_yolo_notebook), and you can create and share detailed [Reports](https://wandb.ai/glenn-jocher/yolov5_tutorial/reports/YOLOv5-COCO128-Tutorial-Results--VmlldzozMDI5OTY) of your results. For more information see the [YOLOv5 Weights & Biases Tutorial](https://github.com/ultralytics/yolov5/issues/1289).
#
# <p align="left"><img width="900" alt="Weights & Biases dashboard" src="https://user-images.githubusercontent.com/26833433/135390767-c28b050f-8455-4004-adb0-3b730386e2b2.png"></p>

# %% [markdown]
# ## Local Logging
#
# All results are logged by default to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc. View train and val jpgs to see mosaics, labels, predictions and augmentation effects. Note an Ultralytics **Mosaic Dataloader** is used for training (shown below), which combines 4 images into 1 mosaic during training.
#
# > <img src="https://user-images.githubusercontent.com/26833433/131255960-b536647f-7c61-4f60-bbc5-cb2544d71b2a.jpg" width="700">
# `train_batch0.jpg` shows train batch 0 mosaics and labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/131256748-603cafc7-55d1-4e58-ab26-83657761aed9.jpg" width="700">
# `test_batch0_labels.jpg` shows val batch 0 labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/131256752-3f25d7a5-7b0f-4bb3-ab78-46343c3800fe.jpg" width="700">
# `test_batch0_pred.jpg` shows val batch 0 _predictions_
#
# Training results are automatically logged to [Tensorboard](https://www.tensorflow.org/tensorboard) and [CSV](https://github.com/ultralytics/yolov5/pull/4148) as `results.csv`, which is plotted as `results.png` (below) after training completes. You can also plot any `results.csv` file manually:
#
# ```python
# from utils.plots import plot_results
# plot_results('path/to/results.csv')  # plot 'results.csv' as 'results.png'
# ```
#
# <img align="left" width="800" alt="COCO128 Training Results" src="https://user-images.githubusercontent.com/26833433/126906780-8c5e2990-6116-4de6-b78a-367244a33ccf.png">

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Google Colab and Kaggle** notebooks with free GPU: <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/GCP-Quickstart)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/AWS-Quickstart)
# - **Docker Image**. See [Docker Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/Docker-Quickstart) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![CI CPU testing](https://github.com/ultralytics/yolov5/workflows/CI%20CPU%20testing/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([val.py](https://github.com/ultralytics/yolov5/blob/master/val.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/export.py)) on macOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Optional extras below. Unit tests validate repo functionality and should be run on any PRs submitted.

# %%
# Reproduce
for x in 'yolov5n', 'yolov5s', 'yolov5m', 'yolov5l', 'yolov5x':
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --task speed  # speed
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.001 --iou 0.65  # mAP

# %%
# PyTorch Hub
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Images
dir = 'https://ultralytics.com/images/'
imgs = [dir + f for f in ('zidane.jpg', 'bus.jpg')]  # batch of images

# Inference
results = model(imgs)
results.print()  # or .show(), .save()

# %%
# CI Checks
# %%shell
export PYTHONPATH="$PWD"  # to run *.py. files in subdirectories
rm -rf runs  # remove runs/
for m in yolov5n; do  # models
  python train.py --img 64 --batch 32 --weights $m.pt --epochs 1 --device 0  # train pretrained
  python train.py --img 64 --batch 32 --weights '' --cfg $m.yaml --epochs 1 --device 0  # train scratch
  for d in 0 cpu; do  # devices
    python val.py --weights $m.pt --device $d # val official
    python val.py --weights runs/train/exp/weights/best.pt --device $d # val custom
    python detect.py --weights $m.pt --device $d  # detect official
    python detect.py --weights runs/train/exp/weights/best.pt --device $d  # detect custom
  done
  python hubconf.py  # hub
  python models/yolo.py --cfg $m.yaml  # build PyTorch model
  python models/tf.py --weights $m.pt  # build TensorFlow model
  python export.py --img 64 --batch 1 --weights $m.pt --include torchscript onnx  # export
done

# %%
# Profile
from utils.torch_utils import profile

m1 = lambda x: x * torch.sigmoid(x)
m2 = torch.nn.SiLU()
results = profile(input=torch.randn(16, 3, 640, 640), ops=[m1, m2], n=100)

# %%
# Evolve
# !python train.py --img 640 --batch 64 --epochs 100 --data coco128.yaml --weights yolov5s.pt --cache --noautoanchor --evolve
# !d=runs/train/evolve && cp evolve.* $d && zip -r evolve.zip $d && gsutil mv evolve.zip gs://bucket  # upload results (optional)

# %%
# VOC
for b, m in zip([64, 64, 64, 32, 16], ['yolov5n', 'yolov5s', 'yolov5m', 'yolov5l', 'yolov5x']):  # batch, model
  # !python train.py --batch {b} --weights {m}.pt --data VOC.yaml --epochs 50 --img 512 --hyp hyp.VOC.yaml --project VOC --name {m} --cache

# %%
# TensorRT 
# https://docs.nvidia.com/deeplearning/tensorrt/install-guide/index.html#installing-pip
# !pip install -U nvidia-tensorrt --index-url https://pypi.ngc.nvidia.com  # install
# !python export.py --weights yolov5s.pt --include engine --imgsz 640 640 --device 0  # export
# !python detect.py --weights yolov5s.engine --imgsz 640 640 --device 0  # inference
